# 19     98117.910906   277.867946         0.002832
# 20    287062.983361   975.100833         0.003397
# 21    289775.338266  1135.869710         0.003920
# 22    212004.652006   752.676941         0.003550
# 23     75231.933450   270.436549         0.003595
# 24    163699.159946   667.308708         0.004076
# 25    314094.955689  1381.641763         0.004399
# 26    176702.128748   805.873635         0.004561
# 27    176087.719377   812.137436         0.004612
# 28    141162.203742   628.655490         0.004453
# 29     68854.721651   313.573029         0.004554
# ...             ...          ...              ...
# 5556    2999.430891   260.051553         0.086700
# 5557    3775.526243   324.292109         0.085893
# 5558    3823.741144   325.795117         0.085203
# 5559    6181.787862   521.180771         0.084309
# 5560    5227.683853   433.836736         0.082988
# 5561    2965.939531   244.919445         0.082577
# 5562    5165.051439   425.970270         0.082472
# 5563    2942.545855   240.425755         0.081707
# 5564   10425.378501   832.814472         0.079883
# 5565    9527.663390   746.433790         0.078344
# 5566    7282.383145   585.161703         0.080353
# 5567    3395.080216   273.876904         0.080669
# 5568    3321.620652   266.828013         0.080331
# 5569    6122.885475   493.561229         0.080609
# 5570    9523.899944   747.075695         0.078442
# 5571    3038.329976   242.939613         0.079958
# 5572    3329.187635   266.008999         0.079902
# 5573    1417.683891   113.091630         0.079772
# 5574    1779.671927   143.285184         0.080512
# 5575    6525.920827   529.090922         0.081075
# 5576    3240.835413   263.046663         0.081166
# 5577    4509.631942   366.976838         0.081376
# 5578    6610.715289   550.802402         0.083320
# 5579    4923.371520   416.514717         0.084599
# 5580    6164.877735   522.306051         0.084723
# 5581    4401.591448   373.741670         0.084911
# 5582    5693.722885   477.447470         0.083855
# 5583    3061.097736   256.610378         0.083830
# 5584    3651.100950   304.999340         0.083536
# 5585     419.979601    34.881615         0.083055
#
# [5586 rows x 8 columns]

# %%
eth_df.drop('date',axis=1,inplace=True)
eth_df.drop('weightedAverage',axis=1,inplace=True)
eth_df.head()
# Out:
# /Users/jaredarcilla/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/jaredarcilla/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#       close      high       low      open   quoteVolume      volume
# 0  0.005350  0.005488  0.004225  0.005278  62325.494919  304.983198
# 1  0.004621  0.005840  0.004324  0.005101  30462.689907  145.251297
# 2  0.003070  0.004770  0.002620  0.004621  74319.505974  272.400189
# 3  0.003125  0.003870  0.002900  0.003070  44663.608672  153.519259
# 4  0.002940  0.003350  0.002400  0.003000  47119.904955  126.870697

# %%
eth_np = eth_df.as_matrix()

# %%
from sklearn.preprocessing import scale

# %%
X = eth_np[:-1,:]
y = eth_np[1:,0]

# %%
X = scale(X, axis=0, with_mean=True, with_std=True, copy=True)

# %%
train = eth_np[:4469,:]
test = eth_np[4469:, :]

# %%
eth_np.shape
# Out:
# (5586, 6)

# %%
X_train = X[:4469]
y_train = y[:4469]
X_test = X[4469:]
y_test = y[4469:]

# %%
X_train.shape
# Out:
# (4469, 6)

# %%
y_test
# Out:
# array([0.07965001, 0.0791084 , 0.07577189, ..., 0.08429798, 0.083192  ,
#        0.0831    ])

# %%
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
from keras.layers.core import Dense, Dropout, Flatten, Activation
from keras.layers.recurrent import LSTM
from keras.models import Sequential

# %%
from keras import backend as K
from keras.utils.generic_utils import get_custom_objects

def custom_activation(x):
    return abs(x)

get_custom_objects().update({'custom_activation': Activation(custom_activation)})

# %%
model = Sequential()

model.add(LSTM(50, input_shape = (X_train.shape[1], X_train.shape[2]),
              return_sequences = True))

model.add(LSTM(100, return_sequences = True))
model.add(LSTM(100, return_sequences = True))
model.add(Dropout(0.2))

model.add(Flatten())

model.add(Dense(50, activation='linear'))
model.add(Dense(25, activation='linear'))
model.add(Dense(10, activation='linear'))
model.add(Dense(5, activation='linear'))
model.add(Dense(1, activation='linear'))
model.add(Activation(custom_activation))

# %%
model.compile(optimizer='Adam',loss='mae')

# %%
hist = model.fit(
    X_train,
    y_train,
    validation_split = 0.1)
# Out:
# Train on 4022 samples, validate on 447 samples
# Epoch 1/10
# 4022/4022 [==============================] - 5s - loss: 0.0040 - val_loss: 0.0108
# Epoch 2/10
# 4022/4022 [==============================] - 1s - loss: 0.0018 - val_loss: 0.0041
# Epoch 3/10
# 4022/4022 [==============================] - 1s - loss: 0.0013 - val_loss: 0.0062
# Epoch 4/10
# 4022/4022 [==============================] - 1s - loss: 0.0014 - val_loss: 0.0090
# Epoch 5/10
# 4022/4022 [==============================] - 1s - loss: 0.0012 - val_loss: 0.0027
# Epoch 6/10
# 4022/4022 [==============================] - 1s - loss: 0.0012 - val_loss: 0.0117
# Epoch 7/10
# 4022/4022 [==============================] - 1s - loss: 0.0012 - val_loss: 0.0048
# Epoch 8/10
# 4022/4022 [==============================] - 2s - loss: 0.0011 - val_loss: 0.0026
# Epoch 9/10
# 4022/4022 [==============================] - 1s - loss: 0.0012 - val_loss: 0.0034
# Epoch 10/10
# 4022/4022 [==============================] - 1s - loss: 9.8684e-04 - val_loss: 0.0022

# %%
model.evaluate(X_test, y_test)
# Out:
#  960/1116 [========================>.....] - ETA: 0s
# 0.0012319117240394103

# %%
from matplotlib import pyplot as plt

plt.plot(hist.history['loss'], label='train')
plt.plot(hist.history['val_loss'], label='val')
plt.legend()
plt.show()

# %%
predict = model.predict(X_test)

# %%
plt.plot(predict, label='prediction')
plt.plot(y_test, label='actual')
plt.legend()
plt.show()

# %%
from keras.callbacks import EarlyStopping

# %%
model2 = Sequential()

model2.add(LSTM(100, input_shape = (X_train.shape[1], X_train.shape[2]),return_sequences=True))

model2.add(LSTM(100, return_sequences=True))
model2.add(Dense(200))
model2.add(Dropout(0.2))
model2.add(Dense(300))
model2.add(Dropout(0.2))
model2.add(Dense(200))
model2.add(Dropout(0.2))
model2.add(Dense(100))
model2.add(Dropout(0.2))

model2.add(Flatten())

model2.add(Dense(50, activation='linear'))
model2.add(Dense(25, activation='linear'))
model2.add(Dense(10, activation='linear'))
model2.add(Dense(5, activation='linear'))
model2.add(Dense(1, activation='linear'))
model.add(Activation(a))

# %%
model2.compile(optimizer='Adam',loss='mae')

# %%
early = EarlyStopping(monitor='val_loss', mode='auto', patience = 5)

# %%
hist2 = model2.fit(
    X_train,
    y_train,
    validation_split = 0.1,
    callbacks=[early])
plt.plot(hist2.history['loss'], label='train')
plt.plot(hist2.history['val_loss'], label='val')
plt.legend()
plt.show()
# Out:
# Train on 4022 samples, validate on 447 samples
# Epoch 1/10
# 4022/4022 [==============================] - 1s - loss: 0.0019 - val_loss: 0.0031
# Epoch 2/10
# 4022/4022 [==============================] - 1s - loss: 0.0016 - val_loss: 0.0163
# Epoch 3/10
# 4022/4022 [==============================] - 1s - loss: 0.0019 - val_loss: 0.0032
# Epoch 4/10
# 4022/4022 [==============================] - 1s - loss: 0.0017 - val_loss: 0.0078
# Epoch 5/10
# 4022/4022 [==============================] - 1s - loss: 0.0020 - val_loss: 0.0078
# Epoch 6/10
# 4022/4022 [==============================] - 1s - loss: 0.0018 - val_loss: 0.0068
# Epoch 7/10
# 4022/4022 [==============================] - 2s - loss: 0.0018 - val_loss: 0.0070

# %%
model2.evaluate(X_test, y_test)
# Out:
# 1088/1116 [============================>.] - ETA: 0s
# 0.004328500849985948

# %%
predict2 = model2.predict(X_train)

# %%
#plt.plot(predict, label='prediction1')
plt.plot(predict2[:20], label='prediction2')
plt.plot(y_train[:20], label='actual')
plt.legend()
plt.show()

# %%
eth_df.shape
# Out:
# (5586, 6)

# %%
model.save('eth_predictor_v1.h5')
model2.save('eth_predictor_v2.h5')

# %%
model.predict(X_train).shape
# Out:
# (4469, 1)

# %%
all_prediction = np.concatenate((np.zeros((1,1),dtype=float),model.predict(X_train), model.predict(X_test)),axis=0)

# %%
all_prediction.shape
# Out:
# (5586, 1)

# %%
final_df = eth_df.copy()

# %%
final_df.shape
# Out:
# (5586, 6)

# %%
final_df['prediction'] = all_prediction

# %%
final_df
# Out:
#          close      high       low      open    quoteVolume       volume  \
# 0     0.005350  0.005488  0.004225  0.005278   62325.494919   304.983198
# 1     0.004621  0.005840  0.004324  0.005101   30462.689907   145.251297
# 2     0.003070  0.004770  0.002620  0.004621   74319.505974   272.400189
# 3     0.003125  0.003870  0.002900  0.003070   44663.608672   153.519259
# 4     0.002940  0.003350  0.002400  0.003000   47119.904955   126.870697
# 5     0.003149  0.004100  0.002610  0.002884   47505.032130   152.332268
# 6     0.002680  0.003230  0.002680  0.002953   46590.240014   135.203544
# 7     0.002920  0.002966  0.002626  0.002700   23742.411875    64.143947
# 8     0.002810  0.003164  0.002580  0.002920   79685.569523   224.998405
# 9     0.002581  0.003050  0.002500  0.002867   69344.716364   194.574572
# 10    0.002590  0.002730  0.002200  0.002650   54062.524444   129.706688
# 11    0.002351  0.002650  0.002260  0.002629   54603.919587   133.169405
# 12    0.002540  0.002550  0.002310  0.002389   32330.801271    79.747737
# 13    0.002550  0.002557  0.002447  0.002540   35884.314444    90.522521
# 14    0.002600  0.002902  0.002500  0.002545   67731.661503   180.190062
# 15    0.002645  0.002750  0.002504  0.002600   39962.185059   105.028853
# 16    0.002680  0.002700  0.002489  0.002650   89743.189455   232.342852
# 17    0.002550  0.002731  0.002414  0.002680   92641.180339   236.940519
# 18    0.002590  0.002690  0.002510  0.002560   57797.893581   149.152251
# 19    0.002990  0.003000  0.002580  0.002620   98117.910906   277.867946
# 20    0.003860  0.003935  0.002955  0.002980  287062.983361   975.100833
# 21    0.003950  0.004400  0.003441  0.003760  289775.338266  1135.869710
# 22    0.003299  0.004200  0.002910  0.003955  212004.652006   752.676941
# 23    0.003622  0.003871  0.003050  0.003050   75231.933450   270.436549
# 24    0.004500  0.004550  0.003521  0.003560  163699.159946   667.308708
# 25    0.004475  0.004798  0.003990  0.004550  314094.955689  1381.641763
# 26    0.004650  0.004800  0.004311  0.004475  176702.128748   805.873635
# 27    0.004500  0.004882  0.004224  0.004650  176087.719377   812.137436
# 28    0.004530  0.004770  0.004010  0.004500  141162.203742   628.655490
# 29    0.004749  0.004749  0.004364  0.004598   68854.721651   313.573029
# ...        ...       ...       ...       ...            ...          ...
# 5556  0.086588  0.087708  0.086000  0.087351    2999.430891   260.051553
# 5557  0.085420  0.086997  0.084900  0.086588    3775.526243   324.292109
# 5558  0.084521  0.086082  0.084400  0.085420    3823.741144   325.795117
# 5559  0.084086  0.084866  0.083801  0.084521    6181.787862   521.180771
# 5560  0.082643  0.084080  0.082341  0.084080    5227.683853   433.836736
# 5561  0.082287  0.083067  0.082000  0.082785    2965.939531   244.919445
# 5562  0.082115  0.082881  0.081845  0.082287    5165.051439   425.970270
# 5563  0.081485  0.082120  0.081416  0.082065    2942.545855   240.425755
# 5564  0.079200  0.081475  0.078900  0.081475   10425.378501   832.814472
# 5565  0.078715  0.079311  0.077260  0.079200    9527.663390   746.433790
# 5566  0.081005  0.081800  0.078542  0.078715    7282.383145   585.161703
# 5567  0.079999  0.081429  0.079994  0.081000    3395.080216   273.876904
# 5568  0.080718  0.080843  0.079779  0.080030    3321.620652   266.828013
# 5569  0.079482  0.081700  0.079057  0.080652    6122.885475   493.561229
# 5570  0.079450  0.079950  0.077817  0.079234    9523.899944   747.075695
# 5571  0.080260  0.080536  0.079293  0.079450    3038.329976   242.939613
# 5572  0.079522  0.080686  0.079361  0.080260    3329.187635   266.008999
# 5573  0.079985  0.080290  0.079474  0.079522    1417.683891   113.091630
# 5574  0.080794  0.081026  0.079875  0.079985    1779.671927   143.285184
# 5575  0.081000  0.082147  0.080356  0.080794    6525.920827   529.090922
# 5576  0.080810  0.081600  0.080600  0.081000    3240.835413   263.046663
# 5577  0.081636  0.081990  0.080630  0.080810    4509.631942   366.976838
# 5578  0.085655  0.085698  0.081568  0.081782    6610.715289   550.802402
# 5579  0.085051  0.085762  0.082800  0.085415    4923.371520   416.514717
# 5580  0.085550  0.086000  0.083973  0.085023    6164.877735   522.306051
# 5581  0.083945  0.085600  0.083450  0.085455    4401.591448   373.741670
# 5582  0.083603  0.085989  0.082703  0.083945    5693.722885   477.447470
# 5583  0.084298  0.084669  0.083239  0.083570    3061.097736   256.610378
# 5584  0.083192  0.084288  0.082510  0.084288    3651.100950   304.999340
# 5585  0.083100  0.083160  0.082867  0.083160     419.979601    34.881615
#
#       prediction
# 0       0.000000
# 1       0.004893
# 2       0.004733
# 3       0.003541
# 4       0.003044
# 5       0.002726
# 6       0.003014
# 7       0.002662
# 8       0.002603
# 9       0.002657
# 10      0.002532
# 11      0.002339
# 12      0.002253
# 13      0.002248
# 14      0.002310
# 15      0.002427
# 16      0.002414
# 17      0.002417
# 18      0.002377
# 19      0.002371
# 20      0.002611
# 21      0.003394
# 22      0.003825
# 23      0.003430
# 24      0.003231
# 25      0.003921
# 26      0.004382
# 27      0.004390
# 28      0.004389
# 29      0.004270
# ...          ...
# 5556    0.086431
# 5557    0.085419
# 5558    0.084511
# 5559    0.083749
# 5560    0.083106
# 5561    0.082004
# 5562    0.081395
# 5563    0.081222
# 5564    0.080680
# 5565    0.079122
# 5566    0.077759
# 5567    0.079333
# 5568    0.079539
# 5569    0.079470
# 5570    0.079169
# 5571    0.078295
# 5572    0.079049
# 5573    0.078959
# 5574    0.078943
# 5575    0.079540
# 5576    0.080132
# 5577    0.080002
# 5578    0.080360
# 5579    0.082889
# 5580    0.083441
# 5581    0.083940
# 5582    0.083213
# 5583    0.082824
# 5584    0.082833
# 5585    0.082283
#
# [5586 rows x 7 columns]

# %%
final_df.to_csv('predictions.csv')
